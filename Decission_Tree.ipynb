# %% [markdown]
# The name of the dataset i'm using is HR-Employee-Attrition, it was found at (https://www.kaggle.com/datasets/rishikeshkonapure/hr-analytics-prediction), and (https://www.kaggle.com/datasets/ppb00x/country-gdp)This dataset. have  information for an employee, such as salary income, years of service , family, and gdp of the country .Which are the factors that modeling the human behavior in relation to savings and withdrawal patterns in the TwoPot system

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("C:/Users/Admin/Downloads/archive (3)/HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [raw]
# df.describe()

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].astype(float)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df['Attrition'] = df['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data= df.drop(columns=['EmployeeCount', 'EmployeeNumber', 'Over18'])
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df['RecentlyPromoted'] = df['YearsSinceLastPromotion'].apply(lambda x: 1 if x <= 5 else 0)
df['JobSatisfaction_Salary'] = df['JobSatisfaction'] * df['MonthlyIncome']
df['WorkLifeBalance_Satisfaction'] = df['WorkLifeBalance'] * df['JobSatisfaction']

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
from sklearn.model_selection import train_test_split

X = data.drop('Attrition', axis=1)
y = data['Attrition']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=45)

print(f'Training set shape: {X_train.shape}, Training labels shape: {y_train.shape}')
print(f'Testing set shape: {X_test.shape}, Testing labels shape: {y_test.shape}')
# Out:
# Training set shape: (1029, 45), Training labels shape: (1029,)
# Testing set shape: (441, 45), Testing labels shape: (441,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix


dt_model = DecisionTreeClassifier(random_state=45)


dt_model.fit(X_train, y_train)
y_pred = dt_model.predict(X_test)


print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[307  55]
#  [ 43  36]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86       362
#            1       0.40      0.46      0.42        79
#
#     accuracy                           0.78       441
#    macro avg       0.64      0.65      0.64       441
# weighted avg       0.79      0.78      0.78       441

# %%
new_employee = [[35, 10, 60000, 1, 0]]
predicted_withdrawal_dt = dt_model.predict(new_employee)
if predicted_withdrawal_dt[0] == 1:
    print("Decision Tree: The employee is likely to withdraw funds.")
else:
    print("Decision Tree: The employee is unlikely to withdraw funds.")
# Out:
# C:\Users\Admin\mthobisi\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 new_employee = [[35, 10, 60000, 1, 0]]
# ----> 2 predicted_withdrawal_dt = dt_model.predict(new_employee)
#       4 # Interpret the result for Decision Tree
#       5 if predicted_withdrawal_dt[0] == 1:
#
# File ~\mthobisi\Lib\site-packages\sklearn\tree\_classes.py:426, in BaseDecisionTree.predict(self, X, check_input)
#     403 """Predict class or regression value for X.
#     404
#     405 For a classification model, the predicted class for each sample in X is
#    (...)
#     423     The predicted classes, or the predict values.
#     424 """
#     425 check_is_fitted(self)
# ...
